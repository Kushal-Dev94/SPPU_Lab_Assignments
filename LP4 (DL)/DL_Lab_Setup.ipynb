# %%
# =============================================
# Deep Learning Lab Environment Setup (Ubuntu)
# Run this once in Jupyter Notebook
# =============================================

# Upgrade pip to the latest version
# !pip install --upgrade pip

# Install all required packages
# !pip install tensorflow keras numpy pandas matplotlib seaborn scikit-learn pillow tqdm jupyterlab

# Verify installations and print versions
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import sklearn

print("\n✅ Installation Complete!\n")
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print(f"Numpy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")
print(f"scikit-learn version: {sklearn.__version__}")

# Enable inline plotting
# %matplotlib inline
